# %% [markdown]
# Montée en CFL – loi géométrique
#
# Génère `Tab_Params`, `Tab_ValuesParams` et `Tab_Iter` au format attendu par le solveur.

# %%
ite_begin, ite_end = 5, 2000
cfl_begin, cfl_end = 1.0, 200.0
every = 10  # mise à jour tous les combien d'itérations

ratio = cfl_end / cfl_begin

step_iters = list(range(ite_begin, ite_end, every)) + [ite_end]
step_cfls = [
    cfl_begin * ratio ** ((it - ite_begin) / (ite_end - ite_begin))
    for it in step_iters
]

PARAM_NAMES = ["CFL number", "CFL number (coarse grids)"]

Tab_Params = [name for _ in step_cfls for name in PARAM_NAMES]
Tab_ValuesParams = [str(round(cfl, 6)) for cfl in step_cfls for _ in PARAM_NAMES]
Tab_Iter = [it for it in step_iters for _ in PARAM_NAMES]

print(f'Tab_Params = {Tab_Params}')
print(f'Tab_ValuesParams = {Tab_ValuesParams}')
print(f'Tab_Iter = {Tab_Iter}')
# Out:
# Tab_Params = ['CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)', 'CFL number', 'CFL number (coarse grids)']
# Tab_ValuesParams = ['1.0', '1.0', '1.696392', '1.696392', '2.8854', '2.8854', '4.907787', '4.907787', '8.325532', '8.325532', '14.123369', '14.123369', '24.022489', '24.022489', '40.859937', '40.859937', '69.314484', '69.314484', '117.58456', '117.58456', '200.0', '200.0']
# Tab_Iter = [5, 5, 204, 204, 404, 404, 604, 604, 803, 803, 1002, 1002, 1202, 1202, 1402, 1402, 1601, 1601, 1800, 1800, 2000, 2000]

# %% [markdown]
# Plot

# %%
import plotting
import matplotlib.pyplot as plt

plotting.use_style("paper")

fig, ax = plt.subplots()
plotting.plot_line(ax, step_iters, step_cfls)

ax.set_xlabel("ITE")
ax.set_ylabel("CFL")
ax.set_title("CFL vs ITE avec une loi géométrique")
ax.legend()
plt.show()
